# %%
import requests
import random
import json
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Video_Games_Sales_as_at_22_Dec_2016.csv",header=0, encoding='unicode_escape')

# %%
df = df[df['Name'].notna()]

# %%
DS_df = df[df["Name"].str.contains("Dark Souls")]#de esta solo queremos la dataframe en si, para ver las ventas.
BB_df = df[df["Name"].str.contains("Bloodborne")]#No nos olviemos de bloodborne

# %%
DS_df
#Los 2 juegos de DS no nos interesan, son de bleach.
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 845                       Dark Souls      PS3           2011.0  Role-Playing
# 1107                  Dark Souls III      PS4           2016.0  Role-Playing
# 1550                   Dark Souls II      PS3           2014.0  Role-Playing
# 2091                      Dark Souls     X360           2011.0  Role-Playing
# 2756                   Dark Souls II     X360           2014.0  Role-Playing
# 3323                   Dark Souls II      PS4           2015.0  Role-Playing
# 4887                  Dark Souls III     XOne           2016.0  Role-Playing
# 7086                   Dark Souls II     XOne           2015.0  Role-Playing
# 8202                   Dark Souls II       PC           2014.0  Role-Playing
# 8806              Bleach: Dark Souls       DS           2007.0      Fighting
# 10671  Bleach: Dark Souls (JP sales)       DS           2007.0      Fighting
# 11892                 Dark Souls III       PC           2016.0  Role-Playing
# 12235                     Dark Souls       PC           2012.0  Role-Playing
#
#                 Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 845    Namco Bandai Games      0.75      0.51      0.54         0.22
# 1107   Namco Bandai Games      0.65      0.45      0.34         0.22
# 1550   Namco Bandai Games      0.40      0.33      0.40         0.15
# 2091   Namco Bandai Games      0.64      0.27      0.00         0.09
# 2756   Namco Bandai Games      0.48      0.18      0.01         0.07
# 3323   Namco Bandai Games      0.21      0.23      0.08         0.09
# 4887   Namco Bandai Games      0.26      0.09      0.00         0.04
# 7086   Namco Bandai Games      0.14      0.07      0.00         0.02
# 8202   Namco Bandai Games      0.08      0.08      0.00         0.01
# 8806                 Sega      0.12      0.02      0.00         0.01
# 10671                Sega      0.00      0.00      0.10         0.00
# 11892  Namco Bandai Games      0.00      0.07      0.00         0.00
# 12235  Namco Bandai Games      0.00      0.06      0.00         0.01
#
#        Global_Sales  Critic_Score  Critic_Count User_Score  User_Count  \
# 845            2.02          89.0          54.0        8.7      1397.0
# 1107           1.65          89.0          69.0        8.8      1940.0
# 1550           1.27          91.0          69.0        8.1      1107.0
# 2091           0.99          89.0          66.0        8.4      1106.0
# 2756           0.74          91.0          30.0        7.9       915.0
# 3323           0.60           NaN           NaN        NaN         NaN
# 4887           0.39          87.0          14.0        8.6       514.0
# 7086           0.23           NaN           NaN        NaN         NaN
# 8202           0.17          91.0          36.0        7.1      2318.0
# 8806           0.15          82.0          28.0        7.9        14.0
# 10671          0.10           NaN           NaN        NaN         NaN
# 11892          0.07          89.0          56.0        8.6      1848.0
# 12235          0.07           NaN           NaN        NaN         NaN
#
#            Developer Rating
# 845    From Software      M
# 1107   From Software      M
# 1550   From Software      T
# 2091   From Software      M
# 2756   From Software      T
# 3323             NaN    NaN
# 4887   From Software    NaN
# 7086             NaN    NaN
# 8202   From Software      T
# 8806        Treasure      T
# 10671            NaN    NaN
# 11892  From Software      M
# 12235            NaN    NaN

# %%
DSX360_df = DS_df[DS_df["Platform"]=="X360"]
DSPS3_df = DS_df[DS_df["Platform"]=="PS3"]
DSPC_df = DS_df[DS_df["Platform"]=="PC"]
DSPS4_df = DS_df[DS_df["Platform"]=="PS4"]
DSXOne_df = DS_df[DS_df["Platform"]=="XOne"]

# %%
DSPS4_df = pd.concat([DSPS4_df,BB_df])
DSPS4_df
# Out:
#                 Name Platform  Year_of_Release         Genre  \
# 1107  Dark Souls III      PS4           2016.0  Role-Playing
# 3323   Dark Souls II      PS4           2015.0  Role-Playing
# 623       Bloodborne      PS4           2015.0        Action
#
#                         Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 1107           Namco Bandai Games      0.65      0.45      0.34         0.22
# 3323           Namco Bandai Games      0.21      0.23      0.08         0.09
# 623   Sony Computer Entertainment      1.03      0.81      0.26         0.38
#
#       Global_Sales  Critic_Score  Critic_Count User_Score  User_Count  \
# 1107          1.65          89.0          69.0        8.8      1940.0
# 3323          0.60           NaN           NaN        NaN         NaN
# 623           2.48          92.0         100.0        8.6      6383.0
#
#           Developer Rating
# 1107  From Software      M
# 3323            NaN    NaN
# 623   From Software      M

# %%
lista_ventas = {}
lista_ventas["X360"] = DSX360_df["Global_Sales"].sum()
lista_ventas["XOne"] = DSXOne_df["Global_Sales"].sum()
lista_ventas["PS3"] = round(DSPS3_df["Global_Sales"].sum(),2)
lista_ventas["PS4"] = round(DSPS4_df["Global_Sales"].sum(),2)
lista_ventas["PC"] = round(DSPC_df["Global_Sales"].sum(),2)

lista_ventas
# Out:
# {'X360': 1.73, 'XOne': 0.62, 'PS3': 3.29, 'PS4': 4.73, 'PC': 0.31}

# %%
fig, ax = plt.subplots()


ventas = lista_ventas.values()
plataformas = lista_ventas.keys()
bar_labels = ['X360', "XOne","PS3", "PS4","PC"]
bar_colors = ['tab:red', 'tab:blue', 'tab:orange','tab:purple','tab:cyan']

ax.bar(plataformas, ventas, label=bar_labels, color=bar_colors)

ax.set_ylabel('Ventas Globales (Millones)')
ax.set_title('Plataformas')

plt.show()

# %%
DS_df.to_csv("../../Datos procesados/Ventas globales por plataforma Dark Souls.csv")
DSX360_df.to_csv("../../Datos procesados/Ventas X360 Dark Souls.csv")
DSPS3_df.to_csv("../../Datos procesados/Ventas PS3 Dark Souls.csv")
DSPC_df.to_csv("../../Datos procesados/Ventas PC Dark Souls.csv")
DSPS4_df.to_csv("../../Datos procesados/Ventas PS4 Dark Souls.csv")
DSXOne_df.to_csv("../../Datos procesados/Ventas XOne Dark Souls.csv")

lista_ventas = pd.DataFrame(lista_ventas.items(),columns=["Plataforma","Ventas_Globales"])
lista_ventas.to_csv("../../Datos procesados/Ventas globales por plataforma Dark Souls.csv")
